# %% [markdown]
# # Scatter Plot

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_covid = pd.read_csv("D://Sample data//india_covid.csv")
df_covid
# Out:
#            Date Name of State / UT  Latitude  Longitude  cases  death  \
# 0     1/30/2020             Kerala   10.8505    76.2711      1      0
# 1     1/31/2020             Kerala   10.8505    76.2711      1      0
# 2      2/1/2020             Kerala   10.8505    76.2711      2      0
# 3      2/2/2020             Kerala   10.8505    76.2711      3      0
# 4      2/3/2020             Kerala   10.8505    76.2711      3      0
# ...         ...                ...       ...        ...    ...    ...
# 3016  6/15/2020          Telangana   18.1124    79.0193   4974    185
# 3017  6/15/2020            Tripura   23.9408    91.9882   1076      1
# 3018  6/15/2020      Uttar Pradesh   26.8467    80.9462  13615    399
# 3019  6/15/2020        Uttarakhand   30.0668    79.0193   1819     24
# 3020  6/15/2020        West Bengal   22.9868    87.8550  11087    475
#
#       Cured/Discharged/Migrated  New cases  New deaths  New recovered
# ...

# %%
x = df_covid['death']
y = df_covid['cases']

# %% [markdown]
# # plotting scatter

# %%
plt.scatter(x,y)
plt.title("India Covid", fontsize = 21) #this gives title to graph
plt.xlabel('Deaths', fontsize = 12) #gives label to x axis
plt.ylabel('Cases', fontsize = 12) #gives label to y axis
# Out:
# Text(0, 0.5, 'Cases')

# %% [markdown]
# # changing color

# %%
plt.scatter(x,y, c='m')
plt.title("India Covid", fontsize = 21) #this gives title to graph
plt.xlabel('Deaths', fontsize = 12) #gives label to x axis
plt.ylabel('Cases', fontsize = 12) #gives label to y axis
# Out:
# Text(0, 0.5, 'Cases')

# %% [markdown]
# # Changing plot size

# %%
plt.figure(figsize=(16,9))
plt.scatter(x,y, c='m')
plt.title("India Covid", fontsize = 21) #this gives title to graph
plt.xlabel('Deaths', fontsize = 12) #gives label to x axis
plt.ylabel('Cases', fontsize = 12) #gives label to y axis
# Out:
# Text(0, 0.5, 'Cases')

# %% [markdown]
# # Changing Marker

# %%
plt.figure(figsize=(16,9))
plt.scatter(x,y, c='m', marker = '*')
plt.title("India Covid", fontsize = 21) #this gives title to graph
plt.xlabel('Deaths', fontsize = 12) #gives label to x axis
plt.ylabel('Cases', fontsize = 12) #gives label to y axis
# Out:
# Text(0, 0.5, 'Cases')

# %% [markdown]
# # Changing marker size

# %%
plt.figure(figsize=(16,9))
plt.scatter(x,y, c='m', marker = '*', s=90)
plt.title("India Covid", fontsize = 21) #this gives title to graph
plt.xlabel('Deaths', fontsize = 12) #gives label to x axis
plt.ylabel('Cases', fontsize = 12) #gives label to y axis
# Out:
# Text(0, 0.5, 'Cases')

# %% [markdown]
# # Changing transparency

# %%
plt.figure(figsize=(16,9))
plt.scatter(x,y, c='m', marker = '*', s = 90, alpha = 0.6)
plt.title("India Covid", fontsize = 21) #this gives title to graph
plt.xlabel('Deaths', fontsize = 12) #gives label to x axis
plt.ylabel('Cases', fontsize = 12) #gives label to y axis
# Out:
# Text(0, 0.5, 'Cases')

# %% [markdown]
# # Changing marker border color

# %%
plt.figure(figsize=(16,9))
plt.scatter(x,y, c='g', marker = '*', s = 90, alpha = 0.9, edgecolor='r')
plt.title("India Covid", fontsize = 21) #this gives title to graph
plt.xlabel('Deaths', fontsize = 12) #gives label to x axis
plt.ylabel('Cases', fontsize = 12) #gives label to y axis
# Out:
# Text(0, 0.5, 'Cases')

# %% [markdown]
# # Changing marker border width

# %%
plt.figure(figsize=(16,9))
plt.scatter(x,y, c='g', marker = '*', s = 120, alpha = 0.9, edgecolor='r', linewidth=3)
plt.title("India Covid", fontsize = 21) #this gives title to graph
plt.xlabel('Deaths', fontsize = 12) #gives label to x axis
plt.ylabel('Cases', fontsize = 12) #gives label to y axis
# Out:
# Text(0, 0.5, 'Cases')

# %%
#Try yourself: Multiple Scatter
