# %% [markdown]
# # replace() Parameters

# %%
import pandas as pd

# %%
df = pd.read_csv('D:\\Sample data\\pokemon.csv')
df
# Out:
#     Pokemon   id      species  generation_id  height  weight  base_experience  \
# 0       Yes    1    bulbasaur              1     0.7     6.9               64
# 1       Yes    2          NaN              1     1.0    13.0              142
# 2       Yes    3          NaN              1     2.0   100.0              236
# 3       Yes    4   charmander              1     0.6     8.5               62
# 4       Yes    5   charmeleon              1     1.1    19.0              142
# ..      ...  ...          ...            ...     ...     ...              ...
# 802     Yes  803      poipole              7     0.6     1.8              189
# 803     Yes  804    naganadel              7     3.6   150.0              243
# 804     Yes  805    stakataka              7     5.5   820.0              257
# 805     Yes  806  blacephalon              7     1.8    13.0              257
# 806     Yes  807      zeraora              7     1.5    44.5              270
#
# ...

# %%
#string replacement
df.replace('poison', 'Botulinum toxin') #poison string is replaced with Botulinum toxin(most toxic substance in world) string
# Out:
#     Pokemon   id      species  generation_id  height  weight  base_experience  \
# 0       Yes    1    bulbasaur              1     0.7     6.9               64
# 1       Yes    2          NaN              1     1.0    13.0              142
# 2       Yes    3          NaN              1     2.0   100.0              236
# 3       Yes    4   charmander              1     0.6     8.5               62
# 4       Yes    5   charmeleon              1     1.1    19.0              142
# ..      ...  ...          ...            ...     ...     ...              ...
# 802     Yes  803      poipole              7     0.6     1.8              189
# 803     Yes  804    naganadel              7     3.6   150.0              243
# 804     Yes  805    stakataka              7     5.5   820.0              257
# 805     Yes  806  blacephalon              7     1.8    13.0              257
# 806     Yes  807      zeraora              7     1.5    44.5              270
#
# ...

# %%
#integer replacement
df.replace(80, 123456789) # 80 is replaced with 123456789
# Out:
#     Pokemon   id      species  generation_id  height  weight  base_experience  \
# 0       Yes    1    bulbasaur              1     0.7     6.9               64
# 1       Yes    2          NaN              1     1.0    13.0              142
# 2       Yes    3          NaN              1     2.0   100.0              236
# 3       Yes    4   charmander              1     0.6     8.5               62
# 4       Yes    5   charmeleon              1     1.1    19.0              142
# ..      ...  ...          ...            ...     ...     ...              ...
# 802     Yes  803      poipole              7     0.6     1.8              189
# 803     Yes  804    naganadel              7     3.6   150.0              243
# 804     Yes  805    stakataka              7     5.5   820.0              257
# 805     Yes  806  blacephalon              7     1.8    13.0              257
# 806     Yes  807      zeraora              7     1.5    44.5              270
#
# ...

# %%
#replacing more than one value
df.replace([1,3,5,803,805,807,80], "HASH") #list values will be repalced by HASH

#Try it yourself: replace list of values with list
# Out:
#     Pokemon    id      species generation_id height weight base_experience  \
# 0       Yes  HASH    bulbasaur          HASH    0.7    6.9              64
# 1       Yes     2          NaN          HASH   HASH     13             142
# 2       Yes  HASH          NaN          HASH      2    100             236
# 3       Yes     4   charmander          HASH    0.6    8.5              62
# 4       Yes  HASH   charmeleon          HASH    1.1     19             142
# ..      ...   ...          ...           ...    ...    ...             ...
# 802     Yes  HASH      poipole             7    0.6    1.8             189
# 803     Yes   804    naganadel             7    3.6    150             243
# 804     Yes  HASH    stakataka             7    5.5    820             257
# 805     Yes   806  blacephalon             7    1.8     13             257
# 806     Yes  HASH      zeraora             7    1.5   44.5             270
#
#        type_1  type_2    hp attack defense speed special-attack  \
# ...

# %%
#replacing specific column values
#we'll need to use industry
df.replace({"type_1": "fire", 'speed':80}, 'FIRE') #in list type_1 and speed, fire and 80 are replaced with Fire
# Out:
#     Pokemon   id      species  generation_id  height  weight  base_experience  \
# 0       Yes    1    bulbasaur              1     0.7     6.9               64
# 1       Yes    2          NaN              1     1.0    13.0              142
# 2       Yes    3          NaN              1     2.0   100.0              236
# 3       Yes    4   charmander              1     0.6     8.5               62
# 4       Yes    5   charmeleon              1     1.1    19.0              142
# ..      ...  ...          ...            ...     ...     ...              ...
# 802     Yes  803      poipole              7     0.6     1.8              189
# 803     Yes  804    naganadel              7     3.6   150.0              243
# 804     Yes  805    stakataka              7     5.5   820.0              257
# 805     Yes  806  blacephalon              7     1.8    13.0              257
# 806     Yes  807      zeraora              7     1.5    44.5              270
#
# ...

# %% [markdown]
# # regex()

# %%
#regex stands for regular expresion
df.replace('[a-z]', 0, regex = True) #all letters from a to z are replaced with zero
# Out:
#      Pokemon   id  species  generation_id  height  weight  base_experience  \
# 0          0    1      0.0              1     0.7     6.9               64
# 1          0    2      NaN              1     1.0    13.0              142
# 2          0    3      NaN              1     2.0   100.0              236
# 3          0    4      0.0              1     0.6     8.5               62
# 4          0    5      0.0              1     1.1    19.0              142
# ..       ...  ...      ...            ...     ...     ...              ...
# 802        0  803      0.0              7     0.6     1.8              189
# 803        0  804      0.0              7     3.6   150.0              243
# 804        0  805      0.0              7     5.5   820.0              257
# 805        0  806      0.0              7     1.8    13.0              257
# 806        0  807      0.0              7     1.5    44.5              270
#
#      type_1  type_2  hp  attack  defense  speed  special-attack  \
# ...

# %%
#replacing strings in specific column
#we'll use dictionary for this
df.replace({'species':'[a-z]'}, '0', regex = True) #all letters from a to z in the column species are replaced with zero

#note: in above example 0 was given as integer but here it given as string
# Out:
#     Pokemon   id      species  generation_id  height  weight  base_experience  \
# 0       Yes    1    000000000              1     0.7     6.9               64
# 1       Yes    2          NaN              1     1.0    13.0              142
# 2       Yes    3          NaN              1     2.0   100.0              236
# 3       Yes    4   0000000000              1     0.6     8.5               62
# 4       Yes    5   0000000000              1     1.1    19.0              142
# ..      ...  ...          ...            ...     ...     ...              ...
# 802     Yes  803      0000000              7     0.6     1.8              189
# 803     Yes  804    000000000              7     3.6   150.0              243
# 804     Yes  805    000000000              7     5.5   820.0              257
# 805     Yes  806  00000000000              7     1.8    13.0              257
# 806     Yes  807      0000000              7     1.5    44.5              270
#
# ...

# %% [markdown]
# # method()

# %%
df.replace('fire', method = 'ffill') #replaced fire with the previous value       ffill stands for forward fill
#instead of ffill we can also use 'pad'(which is default method value in repalce)

#Try it yourself: bfill method
# Out:
#     Pokemon   id      species  generation_id  height  weight  base_experience  \
# 0       Yes    1    bulbasaur              1     0.7     6.9               64
# 1       Yes    2          NaN              1     1.0    13.0              142
# 2       Yes    3          NaN              1     2.0   100.0              236
# 3       Yes    4   charmander              1     0.6     8.5               62
# 4       Yes    5   charmeleon              1     1.1    19.0              142
# ..      ...  ...          ...            ...     ...     ...              ...
# 802     Yes  803      poipole              7     0.6     1.8              189
# 803     Yes  804    naganadel              7     3.6   150.0              243
# 804     Yes  805    stakataka              7     5.5   820.0              257
# 805     Yes  806  blacephalon              7     1.8    13.0              257
# 806     Yes  807      zeraora              7     1.5    44.5              270
#
# ...

# %% [markdown]
# # limit()

# %%
#limited values are replaced
df.replace('fire', method = 'ffill', limit = 1) #1 fire value is replaced with previous value
# Out:
#     Pokemon   id      species  generation_id  height  weight  base_experience  \
# 0       Yes    1    bulbasaur              1     0.7     6.9               64
# 1       Yes    2          NaN              1     1.0    13.0              142
# 2       Yes    3          NaN              1     2.0   100.0              236
# 3       Yes    4   charmander              1     0.6     8.5               62
# 4       Yes    5   charmeleon              1     1.1    19.0              142
# ..      ...  ...          ...            ...     ...     ...              ...
# 802     Yes  803      poipole              7     0.6     1.8              189
# 803     Yes  804    naganadel              7     3.6   150.0              243
# 804     Yes  805    stakataka              7     5.5   820.0              257
# 805     Yes  806  blacephalon              7     1.8    13.0              257
# 806     Yes  807      zeraora              7     1.5    44.5              270
#
# ...

# %% [markdown]
# # inplace()

# %%
#it does not create a new data frame but modify the orginal data frame
#values to this are given in boolean
df.replace(80, 12345, inplace = True) #all NaN values are given modified with 3
df
# Out:
#     Pokemon   id      species  generation_id  height  weight  base_experience  \
# 0       Yes    1    bulbasaur              1     0.7     6.9               64
# 1       Yes    2          NaN              1     1.0    13.0              142
# 2       Yes    3          NaN              1     2.0   100.0              236
# 3       Yes    4   charmander              1     0.6     8.5               62
# 4       Yes    5   charmeleon              1     1.1    19.0              142
# ..      ...  ...          ...            ...     ...     ...              ...
# 802     Yes  803      poipole              7     0.6     1.8              189
# 803     Yes  804    naganadel              7     3.6   150.0              243
# 804     Yes  805    stakataka              7     5.5   820.0              257
# 805     Yes  806  blacephalon              7     1.8    13.0              257
# 806     Yes  807      zeraora              7     1.5    44.5              270
#
# ...
