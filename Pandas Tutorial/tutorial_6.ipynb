# %% [markdown]
# # read_csv functions

# %%
import pandas as pd

# %%
df1 = pd.read_csv('D:\\Sample data\\pokemon.csv')
df1
# Out:
#     Pokemon   id      species  generation_id  height  weight  base_experience  \
# 0       Yes    1    bulbasaur              1     0.7     6.9               64
# 1       Yes    2      ivysaur              1     1.0    13.0              142
# 2       Yes    3     venusaur              1     2.0   100.0              236
# 3       Yes    4   charmander              1     0.6     8.5               62
# 4       Yes    5   charmeleon              1     1.1    19.0              142
# ..      ...  ...          ...            ...     ...     ...              ...
# 802     Yes  803      poipole              7     0.6     1.8              189
# 803     Yes  804    naganadel              7     3.6   150.0              243
# 804     Yes  805    stakataka              7     5.5   820.0              257
# 805     Yes  806  blacephalon              7     1.8    13.0              257
# 806     Yes  807      zeraora              7     1.5    44.5              270
#
# ...

# %% [markdown]
# # head()

# %%
#head function print the top five rows(default) of the csv file
df1.head()
# Out:
#   Pokemon  id     species  generation_id  height  weight  base_experience  \
# 0     Yes   1   bulbasaur              1     0.7     6.9               64
# 1     Yes   2     ivysaur              1     1.0    13.0              142
# 2     Yes   3    venusaur              1     2.0   100.0              236
# 3     Yes   4  charmander              1     0.6     8.5               62
# 4     Yes   5  charmeleon              1     1.1    19.0              142
#
#   type_1  type_2  hp  attack  defense  speed  special-attack  special-defense
# 0  grass  poison  45      49       49     45              65               65
# 1  grass  poison  60      62       63     60              80               80
# 2  grass  poison  80      82       83     80             100              100
# 3   fire     NaN  39      52       43     65              60               50
# 4   fire     NaN  58      64       58     80              80               65

# %%
#for specific data rows from the top
df1.head(3)
# Out:
#   Pokemon  id    species  generation_id  height  weight  base_experience  \
# 0     Yes   1  bulbasaur              1     0.7     6.9               64
# 1     Yes   2    ivysaur              1     1.0    13.0              142
# 2     Yes   3   venusaur              1     2.0   100.0              236
#
#   type_1  type_2  hp  attack  defense  speed  special-attack  special-defense
# 0  grass  poison  45      49       49     45              65               65
# 1  grass  poison  60      62       63     60              80               80
# 2  grass  poison  80      82       83     80             100              100

# %%
#for specific data rows from the top
df1.head(9)
# Out:
#   Pokemon  id     species  generation_id  height  weight  base_experience  \
# 0     Yes   1   bulbasaur              1     0.7     6.9               64
# 1     Yes   2     ivysaur              1     1.0    13.0              142
# 2     Yes   3    venusaur              1     2.0   100.0              236
# 3     Yes   4  charmander              1     0.6     8.5               62
# 4     Yes   5  charmeleon              1     1.1    19.0              142
# 5     Yes   6   charizard              1     1.7    90.5              240
# 6     Yes   7    squirtle              1     0.5     9.0               63
# 7     Yes   8   wartortle              1     1.0    22.5              142
# 8     Yes   9   blastoise              1     1.6    85.5              239
#
#   type_1  type_2  hp  attack  defense  speed  special-attack  special-defense
# 0  grass  poison  45      49       49     45              65               65
# ...

# %% [markdown]
# # tail()

# %%
#head function print the bottom five rows(default) of the csv file
df1.tail()
# Out:
#     Pokemon   id      species  generation_id  height  weight  base_experience  \
# 802     Yes  803      poipole              7     0.6     1.8              189
# 803     Yes  804    naganadel              7     3.6   150.0              243
# 804     Yes  805    stakataka              7     5.5   820.0              257
# 805     Yes  806  blacephalon              7     1.8    13.0              257
# 806     Yes  807      zeraora              7     1.5    44.5              270
#
#        type_1  type_2  hp  attack  defense  speed  special-attack  \
# 802    poison     NaN  67      73       67     73              73
# 803    poison  dragon  73      73       73    121             127
# 804      rock   steel  61     131      211     13              53
# 805      fire   ghost  53     127       53    107             151
# 806  electric     NaN  88     112       75    143             102
#
#      special-defense
# 802               67
# 803               73
# 804              101
# ...

# %%
#for specific data rows from the botoom
df1.tail(3)
# Out:
#     Pokemon   id      species  generation_id  height  weight  base_experience  \
# 804     Yes  805    stakataka              7     5.5   820.0              257
# 805     Yes  806  blacephalon              7     1.8    13.0              257
# 806     Yes  807      zeraora              7     1.5    44.5              270
#
#        type_1 type_2  hp  attack  defense  speed  special-attack  \
# 804      rock  steel  61     131      211     13              53
# 805      fire  ghost  53     127       53    107             151
# 806  electric    NaN  88     112       75    143             102
#
#      special-defense
# 804              101
# 805               79
# 806               80

# %%
#for specific data rows from the botoom
df1.tail(9)
# Out:
#     Pokemon   id      species  generation_id  height  weight  base_experience  \
# 798     Yes  799     guzzlord              7     5.5   888.0              257
# 799     Yes  800     necrozma              7     2.4   230.0              270
# 800     Yes  801     magearna              7     1.0    80.5              270
# 801     Yes  802    marshadow              7     0.7    22.2              270
# 802     Yes  803      poipole              7     0.6     1.8              189
# 803     Yes  804    naganadel              7     3.6   150.0              243
# 804     Yes  805    stakataka              7     5.5   820.0              257
# 805     Yes  806  blacephalon              7     1.8    13.0              257
# 806     Yes  807      zeraora              7     1.5    44.5              270
#
#        type_1  type_2   hp  attack  defense  speed  special-attack  \
# 798      dark  dragon  223     101       53     43              97
# ...

# %% [markdown]
# # dtype()

# %%
#dtype is used to change the data type of of any column
df1 = pd.read_csv('D:\\Sample data\\pokemon.csv', dtype={'hp': 'float64', 'type_2': 'str'}) #can change multiple data type all at once
df1
# Out:
#     Pokemon   id      species  generation_id  height  weight  base_experience  \
# 0       Yes    1    bulbasaur              1     0.7     6.9               64
# 1       Yes    2      ivysaur              1     1.0    13.0              142
# 2       Yes    3     venusaur              1     2.0   100.0              236
# 3       Yes    4   charmander              1     0.6     8.5               62
# 4       Yes    5   charmeleon              1     1.1    19.0              142
# ..      ...  ...          ...            ...     ...     ...              ...
# 802     Yes  803      poipole              7     0.6     1.8              189
# 803     Yes  804    naganadel              7     3.6   150.0              243
# 804     Yes  805    stakataka              7     5.5   820.0              257
# 805     Yes  806  blacephalon              7     1.8    13.0              257
# 806     Yes  807      zeraora              7     1.5    44.5              270
#
# ...

# %% [markdown]
# # True() and False() values

# %%
#values and string can be converted to true or false
df1 = pd.read_csv('D:\\Sample data\\pokemon.csv', true_values = ['Yes'])
df1
# Out:
#      Pokemon   id      species  generation_id  height  weight  \
# 0       True    1    bulbasaur              1     0.7     6.9
# 1       True    2      ivysaur              1     1.0    13.0
# 2       True    3     venusaur              1     2.0   100.0
# 3       True    4   charmander              1     0.6     8.5
# 4       True    5   charmeleon              1     1.1    19.0
# ..       ...  ...          ...            ...     ...     ...
# 802     True  803      poipole              7     0.6     1.8
# 803     True  804    naganadel              7     3.6   150.0
# 804     True  805    stakataka              7     5.5   820.0
# 805     True  806  blacephalon              7     1.8    13.0
# 806     True  807      zeraora              7     1.5    44.5
#
#      base_experience    type_1  type_2  hp  attack  defense  speed  \
# 0                 64     grass  poison  45      49       49     45
# 1                142     grass  poison  60      62       63     60
# ...

# %%
#values and string can be converted to true or false
df1 = pd.read_csv('D:\\Sample data\\pokemon.csv', false_values = ['Yes'])
df1
# Out:
#      Pokemon   id      species  generation_id  height  weight  \
# 0      False    1    bulbasaur              1     0.7     6.9
# 1      False    2      ivysaur              1     1.0    13.0
# 2      False    3     venusaur              1     2.0   100.0
# 3      False    4   charmander              1     0.6     8.5
# 4      False    5   charmeleon              1     1.1    19.0
# ..       ...  ...          ...            ...     ...     ...
# 802    False  803      poipole              7     0.6     1.8
# 803    False  804    naganadel              7     3.6   150.0
# 804    False  805    stakataka              7     5.5   820.0
# 805    False  806  blacephalon              7     1.8    13.0
# 806    False  807      zeraora              7     1.5    44.5
#
#      base_experience    type_1  type_2  hp  attack  defense  speed  \
# 0                 64     grass  poison  45      49       49     45
# 1                142     grass  poison  60      62       63     60
# ...
