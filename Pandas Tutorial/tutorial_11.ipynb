# %% [markdown]
# # interpolate() function

# %%
#this is used to guess the missing values
#guess is only made for the numeric values

import pandas as pd

# %%
df = pd.read_csv('D:\\Sample data\\pokemon.csv')
df
# Out:
#     Pokemon   id      species  generation_id  height  weight  base_experience  \
# 0       Yes    1    bulbasaur            1.0     0.7     6.9               64
# 1       Yes    2          NaN            1.0     NaN    13.0              142
# 2       Yes    3          NaN            NaN     2.0     NaN              236
# 3       Yes    4   charmander            NaN     NaN     8.5               62
# 4       Yes    5   charmeleon            NaN     NaN    19.0              142
# ..      ...  ...          ...            ...     ...     ...              ...
# 802     Yes  803      poipole            7.0     0.6     1.8              189
# 803     Yes  804    naganadel            7.0     3.6   150.0              243
# 804     Yes  805    stakataka            7.0     5.5   820.0              257
# 805     Yes  806  blacephalon            7.0     1.8    13.0              257
# 806     Yes  807      zeraora            7.0     1.5    44.5              270
#
# ...

# %%
df.interpolate() #possible missing pattern value are intepolated
#by deafult method here is linear i.e. df.interpolate and df.interpolate(method = linear) will give same output

#Try it yourself: make changes in values in csv and see what pattern values can be interpolated
#Strings can't be interpolated
# Out:
#     Pokemon   id      species  generation_id  height  weight  base_experience  \
# 0       Yes    1    bulbasaur            1.0    0.70    6.90               64
# 1       Yes    2          NaN            1.0    1.35   13.00              142
# 2       Yes    3          NaN            1.0    2.00   10.75              236
# 3       Yes    4   charmander            1.0    1.90    8.50               62
# 4       Yes    5   charmeleon            1.0    1.80   19.00              142
# ..      ...  ...          ...            ...     ...     ...              ...
# 802     Yes  803      poipole            7.0    0.60    1.80              189
# 803     Yes  804    naganadel            7.0    3.60  150.00              243
# 804     Yes  805    stakataka            7.0    5.50  820.00              257
# 805     Yes  806  blacephalon            7.0    1.80   13.00              257
# 806     Yes  807      zeraora            7.0    1.50   44.50              270
#
# ...
